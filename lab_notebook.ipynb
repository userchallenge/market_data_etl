# %%
import pandas as pd

template = pd.read_csv("omx_template.csv")
print(template.info())
template
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    5 non-null      object
#  1   open    5 non-null      float64
#  2   high    5 non-null      float64
#  3   low     5 non-null      float64
#  4   close   5 non-null      float64
#  5   volume  5 non-null      int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 372.0+ bytes
# None
#          date    open    high     low   close   volume
# 0  2025-08-07  100.00  102.00   99.50  101.50  1000000
# 1  2025-08-08  101.50  103.25  100.75   99.75  1250000
# 2  2025-08-09   99.75  101.50   98.25  102.25   875000
# 3  2025-08-10  102.25  104.00  101.50  103.10  1500000
# 4  2025-08-11  103.10  105.50  102.75  104.85  1100000

# %%
omx30 = pd.read_csv("omxs30_original.csv")[
    ["Date", "Open", "High", "Low", "Close", "Volume"]
]

# Replace all commas with dots in the entire dataframe
omx30 = omx30.applymap(lambda x: x.replace(",", ".") if isinstance(x, str) else x)

omx30 = omx30.rename(
    columns={
        "Date": "date",
        "Open": "open",
        "High": "high",
        "Low": "low",
        "Close": "close",
        "Volume": "volume",
    }
)

# remove time-component from date
omx30["date"] = omx30["date"].str.split(" ").str[0]


print(omx30.info())
omx30.to_csv(
    "omxs30_cleaned.csv", index=False
)  # Save the cleaned data to a new CSV file
omx30
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1361 entries, 0 to 1360
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1361 non-null   object
#  1   open    1361 non-null   object
#  2   high    1361 non-null   object
#  3   low     1361 non-null   object
#  4   close   1361 non-null   object
#  5   volume  1361 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 63.9+ KB
# None
# /var/folders/8d/zz072l3d0mv392k_mtqd_3tr0000gn/T/ipykernel_62733/3602131639.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   omx30 = omx30.applymap(lambda x: x.replace(",", ".") if isinstance(x, str) else x)
#             date    open    high     low   close  volume
# 0     2020-01-02  682.86  693.83  682.86  693.56       0
# 1     2020-01-03  689.38  689.38  684.22   686.6       0
# 2     2020-01-07   686.8  692.03   686.5  689.23       0
# ...

# %%
import yfinance as yf

ticker_list = [
    "CLVSF",
    "0P0000KSY0",
    "0P00016MNI.ST",
    "0P00000LTH.ST",
    "SE0004841534",
    "SE0011527613",
    "SE0001718388",
    "SE0000531881",
    "0P0001LUE5.ST",
]
# tickers = [yf.Ticker(ticker) for ticker in ticker_list]
ticker = yf.Ticker("SYNT.ST")  # AAPL VOLV-B.ST
data = ticker.history(period="5y")

data  # Display the keys of the data dictionary
# Out:
#                                 Open       High        Low      Close  Volume  \
# Date
# 2020-08-21 00:00:00+02:00  33.160004  33.259586  31.965048  31.965048   37010
# 2020-08-24 00:00:00+02:00  30.272195  32.761687  30.272195  32.562527   13700
# 2020-08-25 00:00:00+02:00  32.562527  32.562527  31.367571  32.164207   19050
# 2020-08-26 00:00:00+02:00  32.363367  32.363367  30.969253  32.164207    6570
# 2020-08-27 00:00:00+02:00  31.168411  32.064629  30.969253  31.865469    7210
# ...                              ...        ...        ...        ...     ...
# 2025-08-14 00:00:00+02:00   3.550000   3.740000   3.450000   3.520000   11527
# 2025-08-15 00:00:00+02:00   3.460000   3.470000   3.340000   3.380000   16813
# 2025-08-18 00:00:00+02:00   3.450000   3.450000   3.430000   3.450000    4285
# 2025-08-19 00:00:00+02:00   3.670000   3.780000   3.450000   3.450000   32284
# 2025-08-20 00:00:00+02:00   3.760000   3.700000   3.700000   3.700000     857
#
# ...
