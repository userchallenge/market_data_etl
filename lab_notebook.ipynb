# %%
import yfinance as yf

ticker_list = [
    "CLVSF",
    "0P0000KSY0",
    "0P00016MNI.ST",
    "0P00000LTH.ST",
    "SE0004841534",
    "SE0011527613",
    "SE0001718388",
    "SE0000531881",
    "0P0001LUE5.ST",
]
# tickers = [yf.Ticker(ticker) for ticker in ticker_list]
ticker = yf.Ticker("SYNT.ST")  # AAPL VOLV-B.ST
data = ticker.history(period="5y")

data  # Display the keys of the data dictionary
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2021-02-04 00:00:00+01:00  34.000000  34.500000  32.599998  34.500000
# 2021-02-05 00:00:00+01:00  34.900002  34.900002  34.000000  34.799999
# 2021-02-08 00:00:00+01:00  33.799999  34.500000  33.799999  34.000000
# 2021-02-09 00:00:00+01:00  35.200001  37.500000  35.200001  37.400002
# 2021-02-10 00:00:00+01:00  37.799999  39.000000  34.200001  39.000000
# ...                              ...        ...        ...        ...
# 2026-01-29 00:00:00+01:00   1.135000   1.135000   1.135000   1.135000
# 2026-01-30 00:00:00+01:00   1.175000   1.175000   1.135000   1.145000
# 2026-02-02 00:00:00+01:00   1.135000   1.150000   1.065000   1.150000
# 2026-02-03 00:00:00+01:00   1.160000   1.220000   1.075000   1.220000
# 2026-02-04 00:00:00+01:00   1.100000   1.260000   1.100000   1.210000
#
#                             Volume  Dividends  Stock Splits
# Date
# 2021-02-04 00:00:00+01:00     6190        0.0           0.0
# 2021-02-05 00:00:00+01:00    32120        0.0           0.0
# 2021-02-08 00:00:00+01:00    27950        0.0           0.0
# 2021-02-09 00:00:00+01:00    46910        0.0           0.0
# 2021-02-10 00:00:00+01:00  1064570        0.0           0.0
# ...                            ...        ...           ...
# 2026-01-29 00:00:00+01:00     1000        0.0           0.0
# 2026-01-30 00:00:00+01:00    11966        0.0           0.0
# 2026-02-02 00:00:00+01:00   328617        0.0           0.0
# 2026-02-03 00:00:00+01:00    72996        0.0           0.0
# 2026-02-04 00:00:00+01:00     3607        0.0           0.0
#
# [1258 rows x 7 columns]

# %%
# Database Query Setup
import pandas as pd
from market_data_etl.database.manager import DatabaseManager

# Initialize database connection
db = DatabaseManager()


def query_to_df(sql_query):
    """Execute SQL query and return results as DataFrame"""
    with db.get_session() as session:
        return pd.read_sql(sql_query, session.connection())


print("✅ Database connection ready")
# Out:
# ✅ Database connection ready

# %%
# Load all database tables as DataFrames
# Get all table names from the database
table_names = query_to_df("SELECT name FROM sqlite_master WHERE type='table'")[
    "name"
].tolist()

print(f"Found {len(table_names)} tables in database:")
print("Loading DataFrames...")

# Create DataFrame for each table
for table_name in table_names:
    df_name = f"df_{table_name}"
    df = query_to_df(f"SELECT * FROM {table_name}")

    # Make the DataFrame available in the notebook environment
    globals()[df_name] = df

    print(f"  {df_name}: {len(df)} rows, {len(df.columns)} columns")

print("\n✅ All tables loaded! Access them as: df_instruments, df_prices, etc.")
# Out:
# Found 15 tables in database:
# Loading DataFrames...
#   df_portfolios: 4 rows, 7 columns
#   df_sqlite_sequence: 9 rows, 2 columns
#   df_economic_indicator_data: 1426 rows, 5 columns
#   df_thresholds: 0 rows, 6 columns
#   df_economic_indicators: 11 rows, 10 columns
#   df_prices: 98545 rows, 10 columns
#   df_income_statements: 323 rows, 29 columns
#   df_balance_sheets: 324 rows, 43 columns
#   df_cash_flows: 334 rows, 35 columns
#   df_financial_ratios: 284 rows, 33 columns
#   df_transactions: 0 rows, 13 columns
#   df_aligned_daily_data: 0 rows, 19 columns
#   df_instruments: 74 rows, 19 columns
#   df_portfolio_holdings: 76 rows, 7 columns
#   df_events: 527 rows, 15 columns
#
# ✅ All tables loaded! Access them as: df_instruments, df_prices, etc.

# %%
df_cash_flows.T
# Out:
#                                                      0    \
# id                                                   278
# instrument_id                                          1
# period_end_date                               2024-09-30
# period_type                                       annual
# fiscal_year                                         2024
# fiscal_quarter                                         3
# currency                                             USD
# net_income                                 93736000000.0
# depreciation_amortization                  11445000000.0
# stock_compensation                         11688000000.0
# deferred_tax                                         NaN
# change_accounts_receivable                          None
# change_inventory                           -1046000000.0
# change_accounts_payable                             None
# change_other_working_capital                3651000000.0
# operating_cash_flow                       118254000000.0
# capital_expenditures                       -9447000000.0
# acquisitions                                        None
# purchases_investments                                NaN
# sales_maturities_investments                        None
# other_investing_activities                          None
# investing_cash_flow                         2935000000.0
# debt_issuance                                        0.0
# debt_repayment                             -9958000000.0
# common_stock_issuance                     -94949000000.0
# common_stock_repurchase                             None
# dividends_paid                            -15234000000.0
# other_financing_activities                          None
# financing_cash_flow                      -121983000000.0
# net_change_cash                                     None
# cash_beginning                             30737000000.0
# cash_ending                                29943000000.0
# free_cash_flow                            108807000000.0
# fcf_per_share                                       None
# created_at                    2025-08-20 04:58:07.450461
#
#                                                      1    \
# id                                                   279
# instrument_id                                          1
# period_end_date                               2023-09-30
# period_type                                       annual
# fiscal_year                                         2023
# fiscal_quarter                                         3
# currency                                             USD
# net_income                                 96995000000.0
# depreciation_amortization                  11519000000.0
# stock_compensation                         10833000000.0
# deferred_tax                                         NaN
# change_accounts_receivable                          None
# change_inventory                           -1618000000.0
# change_accounts_payable                             None
# change_other_working_capital               -6577000000.0
# operating_cash_flow                       110543000000.0
# capital_expenditures                      -10959000000.0
# acquisitions                                        None
# purchases_investments                                NaN
# sales_maturities_investments                        None
# other_investing_activities                          None
# investing_cash_flow                         3705000000.0
# debt_issuance                               5228000000.0
# debt_repayment                            -11151000000.0
# common_stock_issuance                     -77550000000.0
# common_stock_repurchase                             None
# dividends_paid                            -15025000000.0
# other_financing_activities                          None
# financing_cash_flow                      -108488000000.0
# net_change_cash                                     None
# cash_beginning                             24977000000.0
# cash_ending                                30737000000.0
# free_cash_flow                             99584000000.0
# fcf_per_share                                       None
# created_at                    2025-08-20 04:58:07.451427
#
#                                                      2    \
# id                                                   280
# instrument_id                                          1
# period_end_date                               2022-09-30
# period_type                                       annual
# fiscal_year                                         2022
# fiscal_quarter                                         3
# currency                                             USD
# net_income                                 99803000000.0
# depreciation_amortization                  11104000000.0
# stock_compensation                          9038000000.0
# deferred_tax                                 895000000.0
# change_accounts_receivable                          None
# change_inventory                            1484000000.0
# change_accounts_payable                             None
# change_other_working_capital                1200000000.0
# operating_cash_flow                       122151000000.0
# capital_expenditures                      -10708000000.0
# acquisitions                                        None
# purchases_investments                                NaN
# sales_maturities_investments                        None
# other_investing_activities                          None
# investing_cash_flow                       -22354000000.0
# debt_issuance                               5465000000.0
# debt_repayment                             -9543000000.0
# common_stock_issuance                     -89402000000.0
# common_stock_repurchase                             None
# dividends_paid                            -14841000000.0
# other_financing_activities                          None
# financing_cash_flow                      -110749000000.0
# net_change_cash                                     None
# cash_beginning                             35929000000.0
# cash_ending                                24977000000.0
# free_cash_flow                            111443000000.0
# fcf_per_share                                       None
# created_at                    2025-08-20 04:58:07.451979
#
#                                                      3    \
# id                                                   281
# instrument_id                                          1
# period_end_date                               2021-09-30
# period_type                                       annual
# fiscal_year                                         2021
# fiscal_quarter                                         3
# currency                                             USD
# net_income                                           NaN
# depreciation_amortization                            NaN
# stock_compensation                                   NaN
# deferred_tax                               -4774000000.0
# change_accounts_receivable                          None
# change_inventory                                     NaN
# change_accounts_payable                             None
# change_other_working_capital                         NaN
# operating_cash_flow                                  NaN
# capital_expenditures                                 NaN
# acquisitions                                        None
# purchases_investments                                NaN
# sales_maturities_investments                        None
# other_investing_activities                          None
# investing_cash_flow                                  NaN
# debt_issuance                                        NaN
# debt_repayment                                       NaN
# common_stock_issuance                       1105000000.0
# common_stock_repurchase                             None
# dividends_paid                                       NaN
# other_financing_activities                          None
# financing_cash_flow                                  NaN
# net_change_cash                                     None
# cash_beginning                                       NaN
# cash_ending                                          NaN
# free_cash_flow                                       NaN
# fcf_per_share                                       None
# created_at                    2025-08-20 04:58:07.452591
#
#                                                      4    \
# id                                                   282
# instrument_id                                          1
# period_end_date                               2020-09-30
# period_type                                       annual
# fiscal_year                                         2020
# fiscal_quarter                                         3
# currency                                             USD
# net_income                                           NaN
# depreciation_amortization                            NaN
# stock_compensation                                   NaN
# deferred_tax                                -215000000.0
# change_accounts_receivable                          None
# change_inventory                                     NaN
# change_accounts_payable                             None
# change_other_working_capital                         NaN
# operating_cash_flow                                  NaN
# capital_expenditures                                 NaN
# acquisitions                                        None
# purchases_investments                                NaN
# sales_maturities_investments                        None
# other_investing_activities                          None
# investing_cash_flow                                  NaN
# debt_issuance                                        NaN
# debt_repayment                                       NaN
# common_stock_issuance                        880000000.0
# common_stock_repurchase                             None
# dividends_paid                                       NaN
# other_financing_activities                          None
# financing_cash_flow                                  NaN
# net_change_cash                                     None
# cash_beginning                                       NaN
# cash_ending                                          NaN
# free_cash_flow                                       NaN
# fcf_per_share                                       None
# created_at                    2025-08-20 04:58:07.453082
#
#                                                      5    \
# id                                                   283
# instrument_id                                          1
# period_end_date                               2025-06-30
# period_type                                    quarterly
# fiscal_year                                         2025
# fiscal_quarter                                         2
# currency                                             USD
# net_income                                 23434000000.0
# depreciation_amortization                   2830000000.0
# stock_compensation                          3168000000.0
# deferred_tax                                         NaN
# change_accounts_receivable                          None
# change_inventory                             365000000.0
# change_accounts_payable                             None
# change_other_working_capital               -2034000000.0
# operating_cash_flow                        27867000000.0
# capital_expenditures                       -3462000000.0
# acquisitions                                        None
# purchases_investments                                NaN
# sales_maturities_investments                        None
# other_investing_activities                          None
# investing_cash_flow                         5073000000.0
# debt_issuance                              -1192000000.0
# debt_repayment                             -5673000000.0
# common_stock_issuance                     -21075000000.0
# common_stock_repurchase                             None
# dividends_paid                             -3945000000.0
# other_financing_activities                          None
# financing_cash_flow                       -24833000000.0
# net_change_cash                                     None
# cash_beginning                             28162000000.0
# cash_ending                                36269000000.0
# free_cash_flow                             24405000000.0
# fcf_per_share                                       None
# created_at                    2025-08-20 04:58:07.453540
#
#                                                      6    \
# id                                                   284
# instrument_id                                          1
# period_end_date                               2025-03-31
# period_type                                    quarterly
# fiscal_year                                         2025
# fiscal_quarter                                         1
# currency                                             USD
# net_income                                 24780000000.0
# depreciation_amortization                   2661000000.0
# stock_compensation                          3226000000.0
# deferred_tax                                         NaN
# change_accounts_receivable                          None
# change_inventory                             643000000.0
# change_accounts_payable                             None
# change_other_working_capital               -6507000000.0
# operating_cash_flow                        23952000000.0
# capital_expenditures                       -3071000000.0
# acquisitions                                        None
# purchases_investments                                NaN
# sales_maturities_investments                        None
# other_investing_activities                          None
# investing_cash_flow                         2917000000.0
# debt_issuance                              -3000000000.0
# debt_repayment                             -3000000000.0
# common_stock_issuance                     -25898000000.0
# common_stock_repurchase                             None
# dividends_paid                             -3758000000.0
# other_financing_activities                          None
# financing_cash_flow                       -29006000000.0
# net_change_cash                                     None
# cash_beginning                             30299000000.0
# cash_ending                                28162000000.0
# free_cash_flow                             20881000000.0
# fcf_per_share                                       None
# created_at                    2025-08-20 04:58:07.453971
#
#                                                      7    \
# id                                                   285
# instrument_id                                          1
# period_end_date                               2024-12-31
# period_type                                    quarterly
# fiscal_year                                         2024
# fiscal_quarter                                         4
# currency                                             USD
# net_income                                 36330000000.0
# depreciation_amortization                   3080000000.0
# stock_compensation                          3286000000.0
# deferred_tax                                         NaN
# change_accounts_receivable                          None
# change_inventory                             215000000.0
# change_accounts_payable                             None
# change_other_working_capital              -10752000000.0
# operating_cash_flow                        29935000000.0
# capital_expenditures                       -2940000000.0
# acquisitions                                        None
# purchases_investments                                NaN
# sales_maturities_investments                        None
# other_investing_activities                          None
# investing_cash_flow                         9792000000.0
# debt_issuance                              -1009000000.0
# debt_repayment                             -1009000000.0
# common_stock_issuance                     -23606000000.0
# common_stock_repurchase                             None
# dividends_paid                             -3856000000.0
# other_financing_activities                          None
# financing_cash_flow                       -39371000000.0
# net_change_cash                                     None
# cash_beginning                             29943000000.0
# cash_ending                                30299000000.0
# free_cash_flow                             26995000000.0
# fcf_per_share                                       None
# created_at                    2025-08-20 04:58:07.454389
#
#                                                      8    \
# id                                                   286
# instrument_id                                          1
# period_end_date                               2024-09-30
# period_type                                    quarterly
# fiscal_year                                         2024
# fiscal_quarter                                         3
# currency                                             USD
# net_income                                 14736000000.0
# depreciation_amortization                   2911000000.0
# stock_compensation                          2858000000.0
# deferred_tax                                         NaN
# change_accounts_receivable                          None
# change_inventory                           -1087000000.0
# change_accounts_payable                             None
# change_other_working_capital                6608000000.0
# operating_cash_flow                        26811000000.0
# capital_expenditures                       -2908000000.0
# acquisitions                                        None
# purchases_investments                                NaN
# sales_maturities_investments                        None
# other_investing_activities                          None
# investing_cash_flow                         1445000000.0
# debt_issuance                                        0.0
# debt_repayment                             -2558000000.0
# common_stock_issuance                     -25083000000.0
# common_stock_repurchase                             None
# dividends_paid                             -3804000000.0
# other_financing_activities                          None
# financing_cash_flow                       -24948000000.0
# net_change_cash                                     None
# cash_beginning                             26635000000.0
# cash_ending                                29943000000.0
# free_cash_flow                             23903000000.0
# fcf_per_share                                       None
# created_at                    2025-08-20 04:58:07.454804
#
#                                                      9    ...  \
# id                                                   287  ...
# instrument_id                                          1  ...
# period_end_date                               2024-06-30  ...
# period_type                                    quarterly  ...
# fiscal_year                                         2024  ...
# fiscal_quarter                                         2  ...
# currency                                             USD  ...
# net_income                                 21448000000.0  ...
# depreciation_amortization                   2850000000.0  ...
# stock_compensation                          2869000000.0  ...
# deferred_tax                                         NaN  ...
# change_accounts_receivable                          None  ...
# change_inventory                             -12000000.0  ...
# change_accounts_payable                             None  ...
# change_other_working_capital                1684000000.0  ...
# operating_cash_flow                        28858000000.0  ...
# capital_expenditures                       -2151000000.0  ...
# acquisitions                                        None  ...
# purchases_investments                                NaN  ...
# sales_maturities_investments                        None  ...
# other_investing_activities                          None  ...
# investing_cash_flow                         -127000000.0  ...
# debt_issuance                              -4250000000.0  ...
# debt_repayment                             -4250000000.0  ...
# common_stock_issuance                     -26522000000.0  ...
# common_stock_repurchase                             None  ...
# dividends_paid                             -3895000000.0  ...
# other_financing_activities                          None  ...
# financing_cash_flow                       -36017000000.0  ...
# net_change_cash                                     None  ...
# cash_beginning                             33921000000.0  ...
# cash_ending                                26635000000.0  ...
# free_cash_flow                             26707000000.0  ...
# fcf_per_share                                       None  ...
# created_at                    2025-08-20 04:58:07.455242  ...
#
#                                                      324  \
# id                                                   602
# instrument_id                                         74
# period_end_date                               2024-12-31
# period_type                                       annual
# fiscal_year                                         2024
# fiscal_quarter                                         4
# currency                                             USD
# net_income                                  7153000000.0
# depreciation_amortization                   5368000000.0
# stock_compensation                          1999000000.0
# deferred_tax                                 477000000.0
# change_accounts_receivable                          None
# change_inventory                             937000000.0
# change_accounts_payable                             None
# change_other_working_capital                  81000000.0
# operating_cash_flow                        14923000000.0
# capital_expenditures                      -11342000000.0
# acquisitions                                        None
# purchases_investments                                NaN
# sales_maturities_investments                        None
# other_investing_activities                          None
# investing_cash_flow                       -18787000000.0
# debt_issuance                               5744000000.0
# debt_repayment                             -2881000000.0
# common_stock_issuance                                NaN
# common_stock_repurchase                             None
# dividends_paid                                       NaN
# other_financing_activities                          None
# financing_cash_flow                         3853000000.0
# net_change_cash                                     None
# cash_beginning                             17189000000.0
# cash_ending                                17037000000.0
# free_cash_flow                              3581000000.0
# fcf_per_share                                       None
# created_at                    2026-02-02 21:23:25.198133
#
#                                                      325  \
# id                                                   603
# instrument_id                                         74
# period_end_date                               2023-12-31
# period_type                                       annual
# fiscal_year                                         2023
# fiscal_quarter                                         4
# currency                                             USD
# net_income                                 14974000000.0
# depreciation_amortization                   4667000000.0
# stock_compensation                          1812000000.0
# deferred_tax                               -6349000000.0
# change_accounts_receivable                          None
# change_inventory                           -1195000000.0
# change_accounts_payable                             None
# change_other_working_capital               -2248000000.0
# operating_cash_flow                        13256000000.0
# capital_expenditures                       -8899000000.0
# acquisitions                                        None
# purchases_investments                                NaN
# sales_maturities_investments                        None
# other_investing_activities                          None
# investing_cash_flow                       -15584000000.0
# debt_issuance                               3931000000.0
# debt_repayment                             -1815000000.0
# common_stock_issuance                                NaN
# common_stock_repurchase                             None
# dividends_paid                                       NaN
# other_financing_activities                          None
# financing_cash_flow                         2589000000.0
# net_change_cash                                     None
# cash_beginning                             16924000000.0
# cash_ending                                17189000000.0
# free_cash_flow                              4357000000.0
# fcf_per_share                                       None
# created_at                    2026-02-02 21:23:25.198531
#
#                                                      326  \
# id                                                   604
# instrument_id                                         74
# period_end_date                               2022-12-31
# period_type                                       annual
# fiscal_year                                         2022
# fiscal_quarter                                         4
# currency                                             USD
# net_income                                 12587000000.0
# depreciation_amortization                   3747000000.0
# stock_compensation                          1560000000.0
# deferred_tax                                -196000000.0
# change_accounts_receivable                          None
# change_inventory                           -6465000000.0
# change_accounts_payable                             None
# change_other_working_capital               -3712000000.0
# operating_cash_flow                        14724000000.0
# capital_expenditures                       -7172000000.0
# acquisitions                                        None
# purchases_investments                                NaN
# sales_maturities_investments                        None
# other_investing_activities                          None
# investing_cash_flow                       -11973000000.0
# debt_issuance                                        0.0
# debt_repayment                             -3866000000.0
# common_stock_issuance                                0.0
# common_stock_repurchase                             None
# dividends_paid                                       NaN
# other_financing_activities                          None
# financing_cash_flow                        -3527000000.0
# net_change_cash                                     None
# cash_beginning                             18144000000.0
# cash_ending                                16924000000.0
# free_cash_flow                              7552000000.0
# fcf_per_share                                       None
# created_at                    2026-02-02 21:23:25.198906
#
#                                                      327  \
# id                                                   605
# instrument_id                                         74
# period_end_date                               2021-12-31
# period_type                                       annual
# fiscal_year                                         2021
# fiscal_quarter                                         4
# currency                                             USD
# net_income                                           NaN
# depreciation_amortization                            NaN
# stock_compensation                                   NaN
# deferred_tax                                         NaN
# change_accounts_receivable                          None
# change_inventory                                     NaN
# change_accounts_payable                             None
# change_other_working_capital                         NaN
# operating_cash_flow                                  NaN
# capital_expenditures                                 NaN
# acquisitions                                        None
# purchases_investments                                NaN
# sales_maturities_investments                        None
# other_investing_activities                          None
# investing_cash_flow                                  NaN
# debt_issuance                                        NaN
# debt_repayment                                       NaN
# common_stock_issuance                                0.0
# common_stock_repurchase                             None
# dividends_paid                                       NaN
# other_financing_activities                          None
# financing_cash_flow                                  NaN
# net_change_cash                                     None
# cash_beginning                                       NaN
# cash_ending                                          NaN
# free_cash_flow                                       NaN
# fcf_per_share                                       None
# created_at                    2026-02-02 21:23:25.199291
#
#                                                      328  \
# id                                                   606
# instrument_id                                         74
# period_end_date                               2025-12-31
# period_type                                    quarterly
# fiscal_year                                         2025
# fiscal_quarter                                         4
# currency                                             USD
# net_income                                   856000000.0
# depreciation_amortization                   1643000000.0
# stock_compensation                           954000000.0
# deferred_tax                                -111000000.0
# change_accounts_receivable                          None
# change_inventory                            -214000000.0
# change_accounts_payable                             None
# change_other_working_capital                -214000000.0
# operating_cash_flow                         3813000000.0
# capital_expenditures                       -2393000000.0
# acquisitions                                        None
# purchases_investments                                NaN
# sales_maturities_investments                        None
# other_investing_activities                          None
# investing_cash_flow                        -6528000000.0
# debt_issuance                               1354000000.0
# debt_repayment                              -767000000.0
# common_stock_issuance                                NaN
# common_stock_repurchase                             None
# dividends_paid                                       NaN
# other_financing_activities                          None
# financing_cash_flow                          710000000.0
# net_change_cash                                     None
# cash_beginning                             19584000000.0
# cash_ending                                17616000000.0
# free_cash_flow                              1420000000.0
# fcf_per_share                                       None
# created_at                    2026-02-02 21:23:25.199816
#
#                                                      329  \
# id                                                   607
# instrument_id                                         74
# period_end_date                               2025-09-30
# period_type                                    quarterly
# fiscal_year                                         2025
# fiscal_quarter                                         3
# currency                                             USD
# net_income                                  1389000000.0
# depreciation_amortization                   1625000000.0
# stock_compensation                           663000000.0
# deferred_tax                                 225000000.0
# change_accounts_receivable                          None
# change_inventory                            1991000000.0
# change_accounts_payable                             None
# change_other_working_capital                2083000000.0
# operating_cash_flow                         6238000000.0
# capital_expenditures                       -2248000000.0
# acquisitions                                        None
# purchases_investments                                NaN
# sales_maturities_investments                        None
# other_investing_activities                          None
# investing_cash_flow                        -4355000000.0
# debt_issuance                               1182000000.0
# debt_repayment                              -687000000.0
# common_stock_issuance                                NaN
# common_stock_repurchase                             None
# dividends_paid                                       NaN
# other_financing_activities                          None
# financing_cash_flow                          983000000.0
# net_change_cash                                     None
# cash_beginning                             16735000000.0
# cash_ending                                19584000000.0
# free_cash_flow                              3990000000.0
# fcf_per_share                                       None
# created_at                    2026-02-02 21:23:25.200258
#
#                                                      330  \
# id                                                   608
# instrument_id                                         74
# period_end_date                               2025-06-30
# period_type                                    quarterly
# fiscal_year                                         2025
# fiscal_quarter                                         2
# currency                                             USD
# net_income                                  1190000000.0
# depreciation_amortization                   1433000000.0
# stock_compensation                           635000000.0
# deferred_tax                                  52000000.0
# change_accounts_receivable                          None
# change_inventory                            -703000000.0
# change_accounts_payable                             None
# change_other_working_capital                -673000000.0
# operating_cash_flow                         2540000000.0
# capital_expenditures                       -2394000000.0
# acquisitions                                        None
# purchases_investments                                NaN
# sales_maturities_investments                        None
# other_investing_activities                          None
# investing_cash_flow                        -2944000000.0
# debt_issuance                               2425000000.0
# debt_repayment                             -2847000000.0
# common_stock_issuance                                NaN
# common_stock_repurchase                             None
# dividends_paid                                       NaN
# other_financing_activities                          None
# financing_cash_flow                         -222000000.0
# net_change_cash                                     None
# cash_beginning                             17250000000.0
# cash_ending                                16735000000.0
# free_cash_flow                               146000000.0
# fcf_per_share                                       None
# created_at                    2026-02-02 21:23:25.200653
#
#                                                      331  \
# id                                                   609
# instrument_id                                         74
# period_end_date                               2025-03-31
# period_type                                    quarterly
# fiscal_year                                         2025
# fiscal_quarter                                         1
# currency                                             USD
# net_income                                   420000000.0
# depreciation_amortization                   1447000000.0
# stock_compensation                           573000000.0
# deferred_tax                                 -43000000.0
# change_accounts_receivable                          None
# change_inventory                           -1704000000.0
# change_accounts_payable                             None
# change_other_working_capital                -554000000.0
# operating_cash_flow                         2156000000.0
# capital_expenditures                       -1492000000.0
# acquisitions                                        None
# purchases_investments                                NaN
# sales_maturities_investments                        None
# other_investing_activities                          None
# investing_cash_flow                        -1651000000.0
# debt_issuance                                625000000.0
# debt_repayment                             -1349000000.0
# common_stock_issuance                                NaN
# common_stock_repurchase                             None
# dividends_paid                                       NaN
# other_financing_activities                          None
# financing_cash_flow                         -332000000.0
# net_change_cash                                     None
# cash_beginning                             17037000000.0
# cash_ending                                17250000000.0
# free_cash_flow                               664000000.0
# fcf_per_share                                       None
# created_at                    2026-02-02 21:23:25.201026
#
#                                                      332  \
# id                                                   610
# instrument_id                                         74
# period_end_date                               2024-12-31
# period_type                                    quarterly
# fiscal_year                                         2024
# fiscal_quarter                                         4
# currency                                             USD
# net_income                                  2332000000.0
# depreciation_amortization                   1496000000.0
# stock_compensation                           579000000.0
# deferred_tax                                  59000000.0
# change_accounts_receivable                          None
# change_inventory                            2044000000.0
# change_accounts_payable                             None
# change_other_working_capital                1030000000.0
# operating_cash_flow                         4814000000.0
# capital_expenditures                       -2780000000.0
# acquisitions                                        None
# purchases_investments                                NaN
# sales_maturities_investments                        None
# other_investing_activities                          None
# investing_cash_flow                        -7603000000.0
# debt_issuance                               1384000000.0
# debt_repayment                              -807000000.0
# common_stock_issuance                                NaN
# common_stock_repurchase                             None
# dividends_paid                                       NaN
# other_financing_activities                          None
# financing_cash_flow                          985000000.0
# net_change_cash                                     None
# cash_beginning                             18974000000.0
# cash_ending                                17037000000.0
# free_cash_flow                              2034000000.0
# fcf_per_share                                       None
# created_at                    2026-02-02 21:23:25.201431
#
#                                                      333
# id                                                   611
# instrument_id                                         74
# period_end_date                               2025-12-31
# period_type                                          ttm
# fiscal_year                                         2025
# fiscal_quarter                                         4
# currency                                             USD
# net_income                                  3855000000.0
# depreciation_amortization                   6148000000.0
# stock_compensation                          2825000000.0
# deferred_tax                                 123000000.0
# change_accounts_receivable                          None
# change_inventory                            -630000000.0
# change_accounts_payable                             None
# change_other_working_capital                 642000000.0
# operating_cash_flow                        14747000000.0
# capital_expenditures                       -8527000000.0
# acquisitions                                        None
# purchases_investments                                NaN
# sales_maturities_investments                        None
# other_investing_activities                          None
# investing_cash_flow                       -15478000000.0
# debt_issuance                               5586000000.0
# debt_repayment                             -5650000000.0
# common_stock_issuance                                NaN
# common_stock_repurchase                             None
# dividends_paid                                       NaN
# other_financing_activities                          None
# financing_cash_flow                         1139000000.0
# net_change_cash                                     None
# cash_beginning                             17037000000.0
# cash_ending                                17616000000.0
# free_cash_flow                              6220000000.0
# fcf_per_share                                       None
# created_at                    2026-02-02 21:23:25.201818
#
# [35 rows x 334 columns]
